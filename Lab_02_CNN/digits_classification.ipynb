# %% [markdown]
# # Image Classification

# %% [markdown]
# ## Data Loading

# %%
# !unzip /content/digits.zip -d digits
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: digits/train/9/Nine_full (1307).jpg
#   inflating: digits/train/9/Nine_full (380).jpg
#   inflating: digits/train/9/Nine_full (176).jpg
#   inflating: digits/train/9/Nine_full (1493).jpg
#   inflating: digits/train/9/Nine_full (1401).jpg
#   inflating: digits/train/9/Nine_full (1316).jpg
#   inflating: digits/train/9/Nine_full (476).jpg
#   inflating: digits/train/9/Nine_full (913).jpg
#   inflating: digits/train/9/Nine_full (1561).jpg
#   inflating: digits/train/9/Nine_full (1556).jpg
#   inflating: digits/train/9/Nine_full (1348).jpg
#   inflating: digits/train/9/Nine_full (340).jpg
#   inflating: digits/train/9/Nine_full (946).jpg
#   inflating: digits/train/9/Nine_full (1450).jpg
#   inflating: digits/train/9/Nine_full (1047).jpg
#   inflating: digits/train/9/Nine_full (317).jpg
#   inflating: digits/train/9/Nine_full (1650).jpg
#   inflating: digits/train/9/Nine_full (828).jpg
#   inflating: digits/train/9/Nine_full (571).jpg
#   inflating: digits/train/9/Nine_full (1888).jpg
#   inflating: digits/train/9/Nine_full (1541).jpg
#   inflating: digits/train/9/Nine_full (1185).jpg
#   inflating: digits/train/9/Nine_full (1508).jpg
#   inflating: digits/train/9/Nine_full (839).jpg
#   inflating: digits/train/9/Nine_full (1382).jpg
#   inflating: digits/train/9/Nine_full (1633).jpg
#   inflating: digits/train/9/Nine_full (1198).jpg
#   inflating: digits/train/9/Nine_full (474).jpg
#   inflating: digits/train/9/Nine_full (1482).jpg
#   inflating: digits/train/9/Nine_full (1620).jpg
#   inflating: digits/train/9/Nine_full (272).jpg
#   inflating: digits/train/9/Nine_full (1031).jpg
#   inflating: digits/train/9/Nine_full (1536).jpg
#   inflating: digits/train/9/Nine_full (805).jpg
#   inflating: digits/train/9/Nine_full (684).jpg
#   inflating: digits/train/9/Nine_full (616).jpg
#   inflating: digits/train/9/Nine_full (1929).jpg
#   inflating: digits/train/9/Nine_full (216).jpg
#   inflating: digits/train/9/Nine_full (1710).jpg
#   inflating: digits/train/9/Nine_full (327).jpg
#   inflating: digits/train/9/Nine_full (1902).jpg
#   inflating: digits/train/9/Nine_full (1068).jpg
#   inflating: digits/train/9/Nine_full (226).jpg
#   inflating: digits/train/9/Nine_full (201).jpg
#   inflating: digits/train/9/Nine_full (773).jpg
#   inflating: digits/train/9/Nine_full (580).jpg
#   inflating: digits/train/9/Nine_full (1220).jpg
#   inflating: digits/train/9/Nine_full (1910).jpg
#   inflating: digits/train/9/Nine_full (387).jpg
#   inflating: digits/train/9/Nine_full (751).jpg
#   inflating: digits/train/9/Nine_full (182).jpg
#   inflating: digits/train/9/Nine_full (1274).jpg
#   inflating: digits/train/9/Nine_full (235).jpg
#   inflating: digits/train/9/Nine_full (311).jpg
#   inflating: digits/train/9/Nine_full (120).jpg
#   inflating: digits/train/9/Nine_full (1595).jpg
#   inflating: digits/train/9/Nine_full (343).jpg
#   inflating: digits/train/9/Nine_full (414).jpg
#   inflating: digits/train/9/Nine_full (686).jpg
#   inflating: digits/train/9/Nine_full (627).jpg
#   inflating: digits/train/9/Nine_full (421).jpg
#   inflating: digits/train/9/Nine_full (1856).jpg
#   inflating: digits/train/9/Nine_full (94).jpg
#   inflating: digits/train/9/Nine_full (1488).jpg
#   inflating: digits/train/9/Nine_full (1176).jpg
#   inflating: digits/train/9/Nine_full (1942).jpg
#   inflating: digits/train/9/Nine_full (22).jpg
#   inflating: digits/train/9/Nine_full (898).jpg
#   inflating: digits/train/9/Nine_full (1303).jpg
#   inflating: digits/train/9/Nine_full (93).jpg
#   inflating: digits/train/9/Nine_full (1785).jpg
#   inflating: digits/train/9/Nine_full (147).jpg
#   inflating: digits/train/9/Nine_full (841).jpg
#   inflating: digits/train/9/Nine_full (97).jpg
#   inflating: digits/train/9/Nine_full (1227).jpg
#   inflating: digits/train/9/Nine_full (826).jpg
#   inflating: digits/train/9/Nine_full (1221).jpg
#   inflating: digits/train/9/Nine_full (1690).jpg
#   inflating: digits/train/9/Nine_full (1677).jpg
#   inflating: digits/train/9/Nine_full (2011).jpg
#   inflating: digits/train/9/Nine_full (1672).jpg
#   inflating: digits/train/9/Nine_full (1175).jpg
#   inflating: digits/train/9/Nine_full (344).jpg
#   inflating: digits/train/9/Nine_full (600).jpg
#   inflating: digits/train/9/Nine_full (456).jpg
#   inflating: digits/train/9/Nine_full (1855).jpg
#   inflating: digits/train/9/Nine_full (988).jpg
#   inflating: digits/train/9/Nine_full (1588).jpg
#   inflating: digits/train/9/Nine_full (1152).jpg
#   inflating: digits/train/9/Nine_full (546).jpg
#   inflating: digits/train/9/Nine_full (587).jpg
#   inflating: digits/train/9/Nine_full (1297).jpg
#   inflating: digits/train/9/Nine_full (1134).jpg
#   inflating: digits/train/9/Nine_full (1898).jpg
#   inflating: digits/train/9/Nine_full (1971).jpg
#   inflating: digits/train/9/Nine_full (130).jpg
#   inflating: digits/train/9/Nine_full (1210).jpg
#   inflating: digits/train/9/Nine_full (261).jpg
#   inflating: digits/train/9/Nine_full (458).jpg
#   inflating: digits/train/9/Nine_full (109).jpg
#   inflating: digits/train/9/Nine_full (900).jpg
#   inflating: digits/train/9/Nine_full (1470).jpg
#   inflating: digits/train/9/Nine_full (1190).jpg
#   inflating: digits/train/9/Nine_full (1979).jpg
#   inflating: digits/train/9/Nine_full (291).jpg
#   inflating: digits/train/9/Nine_full (1054).jpg
#   inflating: digits/train/9/Nine_full (1576).jpg
#   inflating: digits/train/9/Nine_full (325).jpg
#   inflating: digits/train/9/Nine_full (1740).jpg
#   inflating: digits/train/9/Nine_full (662).jpg
#   inflating: digits/train/9/Nine_full (1144).jpg
#   inflating: digits/train/9/Nine_full (1937).jpg
#   inflating: digits/train/9/Nine_full (1080).jpg
#   inflating: digits/train/9/Nine_full (67).jpg
#   inflating: digits/train/9/Nine_full (1407).jpg
#   inflating: digits/train/9/Nine_full (390).jpg
#   inflating: digits/train/9/Nine_full (1921).jpg
#   inflating: digits/train/9/Nine_full (1410).jpg
#   inflating: digits/train/9/Nine_full (404).jpg
#   inflating: digits/train/9/Nine_full (1717).jpg
#   inflating: digits/train/9/Nine_full (842).jpg
#   inflating: digits/train/9/Nine_full (724).jpg
#   inflating: digits/train/9/Nine_full (1802).jpg
#   inflating: digits/train/9/Nine_full (504).jpg
#   inflating: digits/train/9/Nine_full (694).jpg
#   inflating: digits/train/9/Nine_full (1826).jpg
#   inflating: digits/train/9/Nine_full (121).jpg
#   inflating: digits/train/9/Nine_full (634).jpg
#   inflating: digits/train/9/Nine_full (371).jpg
#   inflating: digits/train/9/Nine_full (873).jpg
#   inflating: digits/train/9/Nine_full (7).jpg
#   inflating: digits/train/9/Nine_full (1928).jpg
#   inflating: digits/train/9/Nine_full (799).jpg
#   inflating: digits/train/9/Nine_full (1887).jpg
#   inflating: digits/train/9/Nine_full (1386).jpg
#   inflating: digits/train/9/Nine_full (892).jpg
#   inflating: digits/train/9/Nine_full (255).jpg
#   inflating: digits/train/9/Nine_full (1371).jpg
#   inflating: digits/train/9/Nine_full (484).jpg
#   inflating: digits/train/9/Nine_full (1207).jpg
#   inflating: digits/train/9/Nine_full (1796).jpg
#   inflating: digits/train/9/Nine_full (1507).jpg
#   inflating: digits/train/9/Nine_full (268).jpg
#   inflating: digits/train/9/Nine_full (85).jpg
#   inflating: digits/train/9/Nine_full (1894).jpg
#   inflating: digits/train/9/Nine_full (482).jpg
#   inflating: digits/train/9/Nine_full (1273).jpg
#   inflating: digits/train/9/Nine_full (1101).jpg
#   inflating: digits/train/9/Nine_full (1426).jpg
#   inflating: digits/train/9/Nine_full (1196).jpg
#   inflating: digits/train/9/Nine_full (786).jpg
#   inflating: digits/train/9/Nine_full (234).jpg
#   inflating: digits/train/9/Nine_full (1583).jpg
#   inflating: digits/train/9/Nine_full (984).jpg
#   inflating: digits/train/9/Nine_full (1702).jpg
#   inflating: digits/train/9/Nine_full (1065).jpg
#   inflating: digits/train/9/Nine_full (1589).jpg
#   inflating: digits/train/9/Nine_full (901).jpg
#   inflating: digits/train/9/Nine_full (1385).jpg
#   inflating: digits/train/9/Nine_full (333).jpg
#   inflating: digits/train/9/Nine_full (274).jpg
#   inflating: digits/train/9/Nine_full (699).jpg
#   inflating: digits/train/9/Nine_full (49).jpg
#   inflating: digits/train/9/Nine_full (330).jpg
#   inflating: digits/train/9/Nine_full (765).jpg
#   inflating: digits/train/9/Nine_full (1178).jpg
#   inflating: digits/train/9/Nine_full (292).jpg
#   inflating: digits/train/9/Nine_full (139).jpg
#   inflating: digits/train/9/Nine_full (952).jpg
#   inflating: digits/train/9/Nine_full (1680).jpg
#   inflating: digits/train/9/Nine_full (1160).jpg
#   inflating: digits/train/9/Nine_full (835).jpg
#   inflating: digits/train/9/Nine_full (936).jpg
#   inflating: digits/train/9/Nine_full (565).jpg
#   inflating: digits/train/9/Nine_full (1829).jpg
#   inflating: digits/train/9/Nine_full (114).jpg
#   inflating: digits/train/9/Nine_full (1119).jpg
#   inflating: digits/train/9/Nine_full (1596).jpg
#   inflating: digits/train/9/Nine_full (1810).jpg
#   inflating: digits/train/9/Nine_full (1939).jpg
#   inflating: digits/train/9/Nine_full (1373).jpg
#   inflating: digits/train/9/Nine_full (921).jpg
#   inflating: digits/train/9/Nine_full (924).jpg
#   inflating: digits/train/9/Nine_full (252).jpg
#   inflating: digits/train/9/Nine_full (646).jpg
#   inflating: digits/train/9/Nine_full (38).jpg
#   inflating: digits/train/9/Nine_full (1476).jpg
#   inflating: digits/train/9/Nine_full (1619).jpg
#   inflating: digits/train/9/Nine_full (1879).jpg
#   inflating: digits/train/9/Nine_full (744).jpg
#   inflating: digits/train/9/Nine_full (115).jpg
#   inflating: digits/train/9/Nine_full (1149).jpg
#   inflating: digits/train/9/Nine_full (1846).jpg
#   inflating: digits/train/9/Nine_full (750).jpg
#   inflating: digits/train/9/Nine_full (703).jpg
#   inflating: digits/train/9/Nine_full (1534).jpg
#   inflating: digits/train/9/Nine_full (1524).jpg
#   inflating: digits/train/9/Nine_full (200).jpg
#   inflating: digits/train/9/Nine_full (464).jpg
#   inflating: digits/train/9/Nine_full (211).jpg
#   inflating: digits/train/9/Nine_full (1973).jpg
#   inflating: digits/train/9/Nine_full (1571).jpg
#   inflating: digits/train/9/Nine_full (584).jpg
#   inflating: digits/train/9/Nine_full (690).jpg
#   inflating: digits/train/9/Nine_full (218).jpg
#   inflating: digits/train/9/Nine_full (1501).jpg
#   inflating: digits/train/9/Nine_full (485).jpg
#   inflating: digits/train/9/Nine_full (1262).jpg
#   inflating: digits/train/9/Nine_full (422).jpg
#   inflating: digits/train/9/Nine_full (625).jpg
#   inflating: digits/train/9/Nine_full (265).jpg
#   inflating: digits/train/9/Nine_full (610).jpg
#   inflating: digits/train/9/Nine_full (920).jpg
#   inflating: digits/train/9/Nine_full (2005).jpg
#   inflating: digits/train/9/Nine_full (1800).jpg
#   inflating: digits/train/9/Nine_full (846).jpg
#   inflating: digits/train/9/Nine_full (1292).jpg
#   inflating: digits/train/9/Nine_full (219).jpg
#   inflating: digits/train/9/Nine_full (141).jpg
#   inflating: digits/train/9/Nine_full (994).jpg
#   inflating: digits/train/9/Nine_full (876).jpg
#   inflating: digits/train/9/Nine_full (1691).jpg
#   inflating: digits/train/9/Nine_full (1795).jpg
#   inflating: digits/train/9/Nine_full (277).jpg
#   inflating: digits/train/9/Nine_full (363).jpg
#   inflating: digits/train/9/Nine_full (918).jpg
#   inflating: digits/train/9/Nine_full (296).jpg
#   inflating: digits/train/9/Nine_full (542).jpg
#   inflating: digits/train/9/Nine_full (709).jpg
#   inflating: digits/train/9/Nine_full (1843).jpg
#   inflating: digits/train/9/Nine_full (673).jpg
#   inflating: digits/train/9/Nine_full (1351).jpg
#   inflating: digits/train/9/Nine_full (75).jpg
#   inflating: digits/train/9/Nine_full (834).jpg
#   inflating: digits/train/9/Nine_full (1309).jpg
#   inflating: digits/train/9/Nine_full (1278).jpg
#   inflating: digits/train/9/Nine_full (623).jpg
#   inflating: digits/train/9/Nine_full (352).jpg
#   inflating: digits/train/9/Nine_full (1039).jpg
#   inflating: digits/train/9/Nine_full (1821).jpg
#   inflating: digits/train/9/Nine_full (71).jpg
#   inflating: digits/train/9/Nine_full (532).jpg
#   inflating: digits/train/9/Nine_full (54).jpg
#   inflating: digits/train/9/Nine_full (1764).jpg
#   inflating: digits/train/9/Nine_full (785).jpg
#   inflating: digits/train/9/Nine_full (736).jpg
#   inflating: digits/train/9/Nine_full (954).jpg
#   inflating: digits/train/9/Nine_full (108).jpg
#   inflating: digits/train/9/Nine_full (1743).jpg
#   inflating: digits/train/9/Nine_full (1146).jpg
#   inflating: digits/train/9/Nine_full (1405).jpg
#   inflating: digits/train/9/Nine_full (1833).jpg
#   inflating: digits/train/9/Nine_full (1591).jpg
#   inflating: digits/train/9/Nine_full (386).jpg
#   inflating: digits/train/9/Nine_full (609).jpg
#   inflating: digits/train/9/Nine_full (1072).jpg
#   inflating: digits/train/9/Nine_full (1413).jpg
#   inflating: digits/train/9/Nine_full (607).jpg
#   inflating: digits/train/9/Nine_full (727).jpg
#   inflating: digits/train/9/Nine_full (286).jpg
#   inflating: digits/train/9/Nine_full (1864).jpg
#   inflating: digits/train/9/Nine_full (466).jpg
#   inflating: digits/train/9/Nine_full (1656).jpg
#   inflating: digits/train/9/Nine_full (1483).jpg
#   inflating: digits/train/9/Nine_full (917).jpg
#   inflating: digits/train/9/Nine_full (1517).jpg
#   inflating: digits/train/9/Nine_full (306).jpg
#   inflating: digits/train/9/Nine_full (1575).jpg
#   inflating: digits/train/9/Nine_full (981).jpg
#   inflating: digits/train/9/Nine_full (1849).jpg
#   inflating: digits/train/9/Nine_full (1950).jpg
#   inflating: digits/train/9/Nine_full (155).jpg
#   inflating: digits/train/9/Nine_full (24).jpg
#   inflating: digits/train/9/Nine_full (1977).jpg
#   inflating: digits/train/9/Nine_full (102).jpg
#   inflating: digits/train/9/Nine_full (1993).jpg
#   inflating: digits/train/9/Nine_full (70).jpg
#   inflating: digits/train/9/Nine_full (486).jpg
#   inflating: digits/train/9/Nine_full (251).jpg
#   inflating: digits/train/9/Nine_full (206).jpg
#   inflating: digits/train/9/Nine_full (1366).jpg
#   inflating: digits/train/9/Nine_full (998).jpg
#   inflating: digits/train/9/Nine_full (659).jpg
#   inflating: digits/train/9/Nine_full (1788).jpg
#   inflating: digits/train/9/Nine_full (1872).jpg
#   inflating: digits/train/9/Nine_full (832).jpg
#   inflating: digits/train/9/Nine_full (452).jpg
#   inflating: digits/train/9/Nine_full (198).jpg
#   inflating: digits/train/9/Nine_full (1532).jpg
#   inflating: digits/train/9/Nine_full (1365).jpg
#   inflating: digits/train/9/Nine_full (1560).jpg
#   inflating: digits/train/9/Nine_full (1943).jpg
#   inflating: digits/train/9/Nine_full (1955).jpg
#   inflating: digits/train/9/Nine_full (1050).jpg
#   inflating: digits/train/9/Nine_full (388).jpg
#   inflating: digits/train/9/Nine_full (192).jpg
#   inflating: digits/train/9/Nine_full (1189).jpg
#   inflating: digits/train/9/Nine_full (425).jpg
#   inflating: digits/train/9/Nine_full (817).jpg
#   inflating: digits/train/9/Nine_full (166).jpg
#   inflating: digits/train/9/Nine_full (802).jpg
#   inflating: digits/train/9/Nine_full (335).jpg
#   inflating: digits/train/9/Nine_full (454).jpg
#   inflating: digits/train/9/Nine_full (175).jpg
#   inflating: digits/train/9/Nine_full (1286).jpg
#   inflating: digits/train/9/Nine_full (460).jpg
#   inflating: digits/train/9/Nine_full (978).jpg
#   inflating: digits/train/9/Nine_full (1505).jpg
#   inflating: digits/train/9/Nine_full (1339).jpg
#   inflating: digits/train/9/Nine_full (57).jpg
#   inflating: digits/train/9/Nine_full (1781).jpg
#   inflating: digits/train/9/Nine_full (359).jpg
#   inflating: digits/train/9/Nine_full (644).jpg
#   inflating: digits/train/9/Nine_full (1121).jpg
#   inflating: digits/train/9/Nine_full (567).jpg
#   inflating: digits/train/9/Nine_full (373).jpg
#   inflating: digits/train/9/Nine_full (402).jpg
#   inflating: digits/train/9/Nine_full (1195).jpg
#   inflating: digits/train/9/Nine_full (1580).jpg
#   inflating: digits/train/9/Nine_full (883).jpg
#   inflating: digits/train/9/Nine_full (1706).jpg
#   inflating: digits/train/9/Nine_full (516).jpg
#   inflating: digits/train/9/Nine_full (558).jpg
#   inflating: digits/train/9/Nine_full (1858).jpg
#   inflating: digits/train/9/Nine_full (1804).jpg
#   inflating: digits/train/9/Nine_full (1026).jpg
#   inflating: digits/train/9/Nine_full (677).jpg
#   inflating: digits/train/9/Nine_full (591).jpg
#   inflating: digits/train/9/Nine_full (1911).jpg
#   inflating: digits/train/9/Nine_full (1554).jpg
#   inflating: digits/train/9/Nine_full (569).jpg
#   inflating: digits/train/9/Nine_full (1494).jpg
#   inflating: digits/train/9/Nine_full (1732).jpg
#   inflating: digits/train/9/Nine_full (1779).jpg
#   inflating: digits/train/9/Nine_full (435).jpg
#   inflating: digits/train/9/Nine_full (1357).jpg
#   inflating: digits/train/9/Nine_full (1465).jpg
#   inflating: digits/train/9/Nine_full (1989).jpg
#   inflating: digits/train/9/Nine_full (1590).jpg
#   inflating: digits/train/9/Nine_full (118).jpg
#   inflating: digits/train/9/Nine_full (855).jpg
#   inflating: digits/train/9/Nine_full (1751).jpg
#   inflating: digits/train/9/Nine_full (1645).jpg
#   inflating: digits/train/9/Nine_full (1346).jpg
#   inflating: digits/train/9/Nine_full (593).jpg
#   inflating: digits/train/9/Nine_full (725).jpg
#   inflating: digits/train/9/Nine_full (1219).jpg
#   inflating: digits/train/9/Nine_full (1885).jpg
#   inflating: digits/train/9/Nine_full (1725).jpg
#   inflating: digits/train/9/Nine_full (672).jpg
#   inflating: digits/train/9/Nine_full (1240).jpg
#   inflating: digits/train/9/Nine_full (748).jpg
#   inflating: digits/train/9/Nine_full (1323).jpg
#   inflating: digits/train/9/Nine_full (814).jpg
#   inflating: digits/train/9/Nine_full (1377).jpg
#   inflating: digits/train/9/Nine_full (1842).jpg
#   inflating: digits/train/9/Nine_full (1023).jpg
#   inflating: digits/train/9/Nine_full (1456).jpg
#   inflating: digits/train/9/Nine_full (47).jpg
#   inflating: digits/train/9/Nine_full (137).jpg
#   inflating: digits/train/9/Nine_full (824).jpg
#   inflating: digits/train/9/Nine_full (1020).jpg
#   inflating: digits/train/9/Nine_full (1676).jpg
#   inflating: digits/train/9/Nine_full (287).jpg
#   inflating: digits/train/9/Nine_full (169).jpg
#   inflating: digits/train/9/Nine_full (1776).jpg
#   inflating: digits/train/9/Nine_full (1059).jpg
#   inflating: digits/train/9/Nine_full (1763).jpg
#   inflating: digits/train/9/Nine_full (140).jpg
#   inflating: digits/train/9/Nine_full (739).jpg
#   inflating: digits/train/9/Nine_full (657).jpg
#   inflating: digits/train/9/Nine_full (1801).jpg
#   inflating: digits/train/9/Nine_full (1406).jpg
#   inflating: digits/train/9/Nine_full (1314).jpg
#   inflating: digits/train/9/Nine_full (986).jpg
#   inflating: digits/train/9/Nine_full (276).jpg
#   inflating: digits/train/9/Nine_full (215).jpg
#   inflating: digits/train/9/Nine_full (1259).jpg
#   inflating: digits/train/9/Nine_full (1455).jpg
#   inflating: digits/train/9/Nine_full (1869).jpg
#   inflating: digits/train/9/Nine_full (119).jpg
#   inflating: digits/train/9/Nine_full (1115).jpg
#   inflating: digits/train/9/Nine_full (1533).jpg
#   inflating: digits/train/9/Nine_full (48).jpg
#   inflating: digits/train/9/Nine_full (1868).jpg
#   inflating: digits/train/9/Nine_full (1611).jpg
#   inflating: digits/train/9/Nine_full (488).jpg
#   inflating: digits/train/9/Nine_full (1285).jpg
#   inflating: digits/train/9/Nine_full (1758).jpg
#   inflating: digits/train/9/Nine_full (361).jpg
#   inflating: digits/train/9/Nine_full (225).jpg
#   inflating: digits/train/9/Nine_full (527).jpg
#   inflating: digits/train/9/Nine_full (1548).jpg
#   inflating: digits/train/9/Nine_full (1244).jpg
#   inflating: digits/train/9/Nine_full (337).jpg
#   inflating: digits/train/9/Nine_full (1668).jpg
#   inflating: digits/train/9/Nine_full (638).jpg
#   inflating: digits/train/9/Nine_full (12).jpg
#   inflating: digits/train/9/Nine_full (1530).jpg
#   inflating: digits/train/9/Nine_full (1416).jpg
#   inflating: digits/train/9/Nine_full (170).jpg
#   inflating: digits/train/9/Nine_full (1621).jpg
#   inflating: digits/train/9/Nine_full (382).jpg
#   inflating: digits/train/9/Nine_full (489).jpg
#   inflating: digits/train/9/Nine_full (60).jpg
#   inflating: digits/train/9/Nine_full (1173).jpg
#   inflating: digits/train/9/Nine_full (1768).jpg
#   inflating: digits/train/9/Nine_full (1617).jpg
#   inflating: digits/train/9/Nine_full (1320).jpg
#   inflating: digits/train/9/Nine_full (1570).jpg
#   inflating: digits/train/9/Nine_full (1919).jpg
#   inflating: digits/train/9/Nine_full (111).jpg
#   inflating: digits/train/9/Nine_full (247).jpg
#   inflating: digits/train/9/Nine_full (259).jpg
#   inflating: digits/train/9/Nine_full (1415).jpg
#   inflating: digits/train/9/Nine_full (379).jpg
#   inflating: digits/train/9/Nine_full (757).jpg
#   inflating: digits/train/9/Nine_full (1608).jpg
#   inflating: digits/train/9/Nine_full (221).jpg
#   inflating: digits/train/9/Nine_full (2007).jpg
#   inflating: digits/train/9/Nine_full (1760).jpg
#   inflating: digits/train/9/Nine_full (293).jpg
#   inflating: digits/train/9/Nine_full (1126).jpg
#   inflating: digits/train/9/Nine_full (1063).jpg
#   inflating: digits/train/9/Nine_full (1951).jpg
#   inflating: digits/train/9/Nine_full (159).jpg
#   inflating: digits/train/9/Nine_full (1503).jpg
#   inflating: digits/train/9/Nine_full (415).jpg
#   inflating: digits/train/9/Nine_full (1713).jpg
#   inflating: digits/train/9/Nine_full (308).jpg
#   inflating: digits/train/9/Nine_full (171).jpg
#   inflating: digits/train/9/Nine_full (1544).jpg
#   inflating: digits/train/9/Nine_full (395).jpg
#   inflating: digits/train/9/Nine_full (449).jpg
#   inflating: digits/train/9/Nine_full (923).jpg
#   inflating: digits/train/9/Nine_full (179).jpg
#   inflating: digits/train/9/Nine_full (1836).jpg
#   inflating: digits/train/9/Nine_full (384).jpg
#   inflating: digits/train/9/Nine_full (55).jpg
#   inflating: digits/train/9/Nine_full (1689).jpg
#   inflating: digits/train/9/Nine_full (965).jpg
#   inflating: digits/train/9/Nine_full (148).jpg
#   inflating: digits/train/9/Nine_full (993).jpg
#   inflating: digits/train/9/Nine_full (995).jpg
#   inflating: digits/train/9/Nine_full (944).jpg
#   inflating: digits/train/9/Nine_full (857).jpg
#   inflating: digits/train/9/Nine_full (648).jpg
#   inflating: digits/train/9/Nine_full (1662).jpg
#   inflating: digits/train/9/Nine_full (1239).jpg
#   inflating: digits/train/9/Nine_full (1076).jpg
#   inflating: digits/train/9/Nine_full (1100).jpg
#   inflating: digits/train/9/Nine_full (1279).jpg
#   inflating: digits/train/9/Nine_full (1235).jpg
#   inflating: digits/train/9/Nine_full (1233).jpg
#   inflating: digits/train/9/Nine_full (269).jpg
#   inflating: digits/train/9/Nine_full (368).jpg
#   inflating: digits/train/9/Nine_full (1623).jpg
#   inflating: digits/train/9/Nine_full (1013).jpg
#   inflating: digits/train/9/Nine_full (1186).jpg
#   inflating: digits/train/9/Nine_full (528).jpg
#   inflating: digits/train/9/Nine_full (715).jpg
#   inflating: digits/train/9/Nine_full (1283).jpg
#   inflating: digits/train/9/Nine_full (1905).jpg
#   inflating: digits/train/9/Nine_full (1280).jpg
#   inflating: digits/train/9/Nine_full (767).jpg
#   inflating: digits/train/9/Nine_full (740).jpg
#   inflating: digits/train/9/Nine_full (1228).jpg
#   inflating: digits/train/9/Nine_full (1093).jpg
#   inflating: digits/train/9/Nine_full (1916).jpg
#   inflating: digits/train/9/Nine_full (273).jpg
#   inflating: digits/train/9/Nine_full (1088).jpg
#   inflating: digits/train/9/Nine_full (13).jpg
#   inflating: digits/train/9/Nine_full (1349).jpg
#   inflating: digits/train/9/Nine_full (914).jpg
#   inflating: digits/train/9/Nine_full (801).jpg
#   inflating: digits/train/9/Nine_full (1805).jpg
#   inflating: digits/train/9/Nine_full (1938).jpg
#   inflating: digits/train/9/Nine_full (416).jpg
#   inflating: digits/train/9/Nine_full (158).jpg
#   inflating: digits/train/9/Nine_full (1388).jpg
#   inflating: digits/train/9/Nine_full (1266).jpg
#   inflating: digits/train/9/Nine_full (442).jpg
#   inflating: digits/train/9/Nine_full (788).jpg
#   inflating: digits/train/9/Nine_full (331).jpg
#   inflating: digits/train/9/Nine_full (334).jpg
#   inflating: digits/train/9/Nine_full (5).jpg
#   inflating: digits/train/9/Nine_full (122).jpg
#   inflating: digits/train/9/Nine_full (1881).jpg
#   inflating: digits/train/9/Nine_full (1172).jpg
#   inflating: digits/train/9/Nine_full (1684).jpg
#   inflating: digits/train/9/Nine_full (470).jpg
#   inflating: digits/train/9/Nine_full (1179).jpg
#   inflating: digits/train/9/Nine_full (1634).jpg
#   inflating: digits/train/9/Nine_full (559).jpg
#   inflating: digits/train/9/Nine_full (1515).jpg
#   inflating: digits/train/9/Nine_full (1004).jpg
#   inflating: digits/train/9/Nine_full (1281).jpg
#   inflating: digits/train/9/Nine_full (1853).jpg
#   inflating: digits/train/9/Nine_full (1550).jpg
#   inflating: digits/train/9/Nine_full (79).jpg
#   inflating: digits/train/9/Nine_full (1648).jpg
#   inflating: digits/train/9/Nine_full (1258).jpg
#   inflating: digits/train/9/Nine_full (157).jpg
#   inflating: digits/train/9/Nine_full (451).jpg
#   inflating: digits/train/9/Nine_full (1230).jpg
#   inflating: digits/train/9/Nine_full (1747).jpg
#   inflating: digits/train/9/Nine_full (578).jpg
#   inflating: digits/train/9/Nine_full (1475).jpg
#   inflating: digits/train/9/Nine_full (650).jpg
#   inflating: digits/train/9/Nine_full (702).jpg
#   inflating: digits/train/9/Nine_full (1138).jpg
#   inflating: digits/train/9/Nine_full (316).jpg
#   inflating: digits/train/9/Nine_full (732).jpg
#   inflating: digits/train/9/Nine_full (366).jpg
#   inflating: digits/train/9/Nine_full (1882).jpg
#   inflating: digits/train/9/Nine_full (552).jpg
#   inflating: digits/train/9/Nine_full (800).jpg
#   inflating: digits/train/9/Nine_full (1777).jpg
#   inflating: digits/train/9/Nine_full (804).jpg
#   inflating: digits/train/9/Nine_full (787).jpg
#   inflating: digits/train/9/Nine_full (1679).jpg
#   inflating: digits/train/9/Nine_full (381).jpg
#   inflating: digits/train/9/Nine_full (1660).jpg
#   inflating: digits/train/9/Nine_full (185).jpg
#   inflating: digits/train/9/Nine_full (613).jpg
#   inflating: digits/train/9/Nine_full (680).jpg
#   inflating: digits/train/9/Nine_full (557).jpg
#   inflating: digits/train/9/Nine_full (1067).jpg
#   inflating: digits/train/9/Nine_full (494).jpg
#   inflating: digits/train/9/Nine_full (850).jpg
#   inflating: digits/train/9/Nine_full (1726).jpg
#   inflating: digits/train/9/Nine_full (1574).jpg
#   inflating: digits/train/9/Nine_full (1037).jpg
#   inflating: digits/train/9/Nine_full (640).jpg
#   inflating: digits/train/9/Nine_full (1762).jpg
#   inflating: digits/train/9/Nine_full (1157).jpg
#   inflating: digits/train/9/Nine_full (1468).jpg
#   inflating: digits/train/9/Nine_full (418).jpg
#   inflating: digits/train/9/Nine_full (537).jpg
#   inflating: digits/train/9/Nine_full (1512).jpg
#   inflating: digits/train/9/Nine_full (222).jpg
#   inflating: digits/train/9/Nine_full (346).jpg
#   inflating: digits/train/9/Nine_full (585).jpg
#   inflating: digits/train/9/Nine_full (603).jpg
#   inflating: digits/train/9/Nine_full (790).jpg
#   inflating: digits/train/9/Nine_full (1539).jpg
#   inflating: digits/train/9/Nine_full (1181).jpg
#   inflating: digits/train/9/Nine_full (711).jpg
#   inflating: digits/train/9/Nine_full (1573).jpg
#   inflating: digits/train/9/Nine_full (271).jpg
#   inflating: digits/train/9/Nine_full (244).jpg
#   inflating: digits/train/9/Nine_full (621).jpg
#   inflating: digits/train/9/Nine_full (742).jpg
#   inflating: digits/train/9/Nine_full (87).jpg
#   inflating: digits/train/9/Nine_full (1302).jpg
#   inflating: digits/train/9/Nine_full (42).jpg
#   inflating: digits/train/9/Nine_full (245).jpg
#   inflating: digits/train/9/Nine_full (495).jpg
#   inflating: digits/train/9/Nine_full (1203).jpg
#   inflating: digits/train/9/Nine_full (737).jpg
#   inflating: digits/train/9/Nine_full (165).jpg
#   inflating: digits/train/9/Nine_full (926).jpg
#   inflating: digits/train/9/Nine_full (633).jpg
#   inflating: digits/train/9/Nine_full (475).jpg
#   inflating: digits/train/9/Nine_full (813).jpg
#   inflating: digits/train/9/Nine_full (806).jpg
#   inflating: digits/train/9/Nine_full (1425).jpg
#   inflating: digits/train/9/Nine_full (970).jpg
#   inflating: digits/train/9/Nine_full (1601).jpg
#   inflating: digits/train/9/Nine_full (1319).jpg
#   inflating: digits/train/9/Nine_full (665).jpg
#   inflating: digits/train/9/Nine_full (1398).jpg
#   inflating: digits/train/9/Nine_full (1835).jpg
#   inflating: digits/train/9/Nine_full (1822).jpg
#   inflating: digits/train/9/Nine_full (429).jpg
#   inflating: digits/train/9/Nine_full (719).jpg
#   inflating: digits/train/9/Nine_full (1765).jpg
#   inflating: digits/train/9/Nine_full (637).jpg
#   inflating: digits/train/9/Nine_full (1304).jpg
#   inflating: digits/train/9/Nine_full (1484).jpg
#   inflating: digits/train/9/Nine_full (51).jpg
#   inflating: digits/train/9/Nine_full (596).jpg
#   inflating: digits/train/9/Nine_full (1652).jpg
#   inflating: digits/train/9/Nine_full (468).jpg
#   inflating: digits/train/9/Nine_full (860).jpg
#   inflating: digits/train/9/Nine_full (107).jpg
#   inflating: digits/train/9/Nine_full (520).jpg
#   inflating: digits/train/9/Nine_full (1305).jpg
#   inflating: digits/train/9/Nine_full (1214).jpg
#   inflating: digits/train/9/Nine_full (566).jpg
#   inflating: digits/train/9/Nine_full (2002).jpg
#   inflating: digits/train/9/Nine_full (483).jpg
#   inflating: digits/train/9/Nine_full (1459).jpg
#   inflating: digits/train/9/Nine_full (356).jpg
#   inflating: digits/train/9/Nine_full (1369).jpg
#   inflating: digits/train/9/Nine_full (643).jpg
#   inflating: digits/train/9/Nine_full (1263).jpg
#   inflating: digits/train/9/Nine_full (541).jpg
#   inflating: digits/train/9/Nine_full (618).jpg
#   inflating: digits/train/9/Nine_full (1197).jpg
#   inflating: digits/train/9/Nine_full (1276).jpg
#   inflating: digits/train/9/Nine_full (1187).jpg
#   inflating: digits/train/9/Nine_full (1265).jpg
#   inflating: digits/train/9/Nine_full (1504).jpg
#   inflating: digits/train/9/Nine_full (1627).jpg
#   inflating: digits/train/9/Nine_full (283).jpg
#   inflating: digits/train/9/Nine_full (884).jpg
#   inflating: digits/train/9/Nine_full (253).jpg
#   inflating: digits/train/9/Nine_full (1890).jpg
#   inflating: digits/train/9/Nine_full (1688).jpg
#   inflating: digits/train/9/Nine_full (783).jpg
#   inflating: digits/train/9/Nine_full (1722).jpg
#   inflating: digits/train/9/Nine_full (1889).jpg
#   inflating: digits/train/9/Nine_full (1913).jpg
#   inflating: digits/train/9/Nine_full (351).jpg
#   inflating: digits/train/9/Nine_full (1038).jpg
#   inflating: digits/train/9/Nine_full (1325).jpg
#   inflating: digits/train/9/Nine_full (1782).jpg
#   inflating: digits/train/9/Nine_full (1257).jpg
#   inflating: digits/train/9/Nine_full (1418).jpg
#   inflating: digits/train/9/Nine_full (1153).jpg
#   inflating: digits/train/9/Nine_full (27).jpg
#   inflating: digits/train/9/Nine_full (1643).jpg
#   inflating: digits/train/9/Nine_full (1746).jpg
#   inflating: digits/train/9/Nine_full (508).jpg
#   inflating: digits/train/9/Nine_full (1177).jpg
#   inflating: digits/train/9/Nine_full (1275).jpg
#   inflating: digits/train/9/Nine_full (1966).jpg
#   inflating: digits/train/9/Nine_full (1566).jpg
#   inflating: digits/train/9/Nine_full (708).jpg
#   inflating: digits/train/9/Nine_full (1133).jpg
#   inflating: digits/train/9/Nine_full (1563).jpg
#   inflating: digits/train/9/Nine_full (1129).jpg
#   inflating: digits/train/9/Nine_full (990).jpg
#   inflating: digits/train/9/Nine_full (53).jpg
#   inflating: digits/train/9/Nine_full (1361).jpg
#   inflating: digits/train/9/Nine_full (1976).jpg
#   inflating: digits/train/9/Nine_full (1727).jpg
#   inflating: digits/train/9/Nine_full (1234).jpg
#   inflating: digits/train/9/Nine_full (1444).jpg
#   inflating: digits/train/9/Nine_full (1848).jpg
#   inflating: digits/train/9/Nine_full (1567).jpg
#   inflating: digits/train/9/Nine_full (45).jpg
#   inflating: digits/train/9/Nine_full (1755).jpg
#   inflating: digits/train/9/Nine_full (145).jpg
#   inflating: digits/train/9/Nine_full (1255).jpg
#   inflating: digits/train/9/Nine_full (606).jpg
#   inflating: digits/train/9/Nine_full (809).jpg
#   inflating: digits/train/9/Nine_full (608).jpg
#   inflating: digits/train/9/Nine_full (710).jpg
#   inflating: digits/train/9/Nine_full (728).jpg
#   inflating: digits/train/9/Nine_full (875).jpg
#   inflating: digits/train/9/Nine_full (232).jpg
#   inflating: digits/train/9/Nine_full (1744).jpg
#   inflating: digits/train/9/Nine_full (1041).jpg
#   inflating: digits/train/9/Nine_full (1024).jpg
#   inflating: digits/train/9/Nine_full (675).jpg
#   inflating: digits/train/9/Nine_full (349).jpg
#   inflating: digits/train/9/Nine_full (1982).jpg
#   inflating: digits/train/9/Nine_full (190).jpg
#   inflating: digits/train/9/Nine_full (1827).jpg
#   inflating: digits/train/9/Nine_full (1731).jpg
#   inflating: digits/train/9/Nine_full (396).jpg
#   inflating: digits/train/9/Nine_full (1671).jpg
#   inflating: digits/train/9/Nine_full (759).jpg
#   inflating: digits/train/9/Nine_full (717).jpg
#   inflating: digits/train/9/Nine_full (1715).jpg
#   inflating: digits/train/9/Nine_full (377).jpg
#   inflating: digits/train/9/Nine_full (1994).jpg
#   inflating: digits/train/9/Nine_full (1642).jpg
#   inflating: digits/train/9/Nine_full (1628).jpg
#   inflating: digits/train/9/Nine_full (1312).jpg
#   inflating: digits/train/9/Nine_full (1871).jpg
#   inflating: digits/train/9/Nine_full (1964).jpg
#   inflating: digits/train/9/Nine_full (1707).jpg
#   inflating: digits/train/9/Nine_full (554).jpg
#   inflating: digits/train/9/Nine_full (815).jpg
#   inflating: digits/train/9/Nine_full (629).jpg
#   inflating: digits/train/9/Nine_full (890).jpg
#   inflating: digits/train/9/Nine_full (1569).jpg
#   inflating: digits/train/9/Nine_full (1478).jpg
#   inflating: digits/train/9/Nine_full (695).jpg
#   inflating: digits/train/9/Nine_full (1208).jpg
#   inflating: digits/train/9/Nine_full (162).jpg
#   inflating: digits/train/9/Nine_full (242).jpg
#   inflating: digits/train/9/Nine_full (365).jpg
#   inflating: digits/train/9/Nine_full (1200).jpg
#   inflating: digits/train/9/Nine_full (525).jpg
#   inflating: digits/train/9/Nine_full (649).jpg
#   inflating: digits/train/9/Nine_full (1666).jpg
#   inflating: digits/train/9/Nine_full (870).jpg
#   inflating: digits/train/9/Nine_full (399).jpg
#   inflating: digits/train/9/Nine_full (512).jpg
#   inflating: digits/train/9/Nine_full (849).jpg
#   inflating: digits/train/9/Nine_full (37).jpg
#   inflating: digits/train/9/Nine_full (19).jpg
#   inflating: digits/train/9/Nine_full (389).jpg
#   inflating: digits/train/9/Nine_full (531).jpg
#   inflating: digits/train/9/Nine_full (605).jpg
#   inflating: digits/train/9/Nine_full (1516).jpg
#   inflating: digits/train/9/Nine_full (1272).jpg
#   inflating: digits/train/9/Nine_full (1400).jpg
#   inflating: digits/train/9/Nine_full (1815).jpg
#   inflating: digits/train/9/Nine_full (300).jpg
#   inflating: digits/train/9/Nine_full (398).jpg
#   inflating: digits/train/9/Nine_full (1669).jpg
#   inflating: digits/train/9/Nine_full (1408).jpg
#   inflating: digits/train/9/Nine_full (1277).jpg
#   inflating: digits/train/9/Nine_full (985).jpg
#   inflating: digits/train/9/Nine_full (1812).jpg
#   inflating: digits/train/9/Nine_full (1193).jpg
#   inflating: digits/train/9/Nine_full (811).jpg
#   inflating: digits/train/9/Nine_full (1016).jpg
#   inflating: digits/train/9/Nine_full (687).jpg
#   inflating: digits/train/9/Nine_full (1491).jpg
#   inflating: digits/train/9/Nine_full (184).jpg
#   inflating: digits/train/9/Nine_full (810).jpg
#   inflating: digits/train/9/Nine_full (827).jpg
#   inflating: digits/train/9/Nine_full (440).jpg
#   inflating: digits/train/9/Nine_full (1033).jpg
#   inflating: digits/train/9/Nine_full (560).jpg
#   inflating: digits/train/9/Nine_full (1056).jpg
#   inflating: digits/train/9/Nine_full (1003).jpg
#   inflating: digits/train/9/Nine_full (1350).jpg
#   inflating: digits/train/9/Nine_full (778).jpg
#   inflating: digits/train/9/Nine_full (1156).jpg
#   inflating: digits/train/9/Nine_full (1970).jpg
#   inflating: digits/train/9/Nine_full (1891).jpg
#   inflating: digits/train/9/Nine_full (1108).jpg
#   inflating: digits/train/9/Nine_full (223).jpg
#   inflating: digits/train/9/Nine_full (467).jpg
#   inflating: digits/train/9/Nine_full (808).jpg
#   inflating: digits/train/9/Nine_full (681).jpg
#   inflating: digits/train/9/Nine_full (353).jpg
#   inflating: digits/train/9/Nine_full (1953).jpg
#   inflating: digits/train/9/Nine_full (1749).jpg
#   inflating: digits/train/9/Nine_full (1557).jpg
#   inflating: digits/train/9/Nine_full (506).jpg
#   inflating: digits/train/9/Nine_full (1340).jpg
#   inflating: digits/train/9/Nine_full (722).jpg
#   inflating: digits/train/9/Nine_full (1236).jpg
#   inflating: digits/train/9/Nine_full (1399).jpg
#   inflating: digits/train/9/Nine_full (1631).jpg
#   inflating: digits/train/9/Nine_full (705).jpg
#   inflating: digits/train/9/Nine_full (490).jpg
#   inflating: digits/train/9/Nine_full (1809).jpg
#   inflating: digits/train/9/Nine_full (444).jpg
#   inflating: digits/train/9/Nine_full (796).jpg
#   inflating: digits/train/9/Nine_full (962).jpg
#   inflating: digits/train/9/Nine_full (410).jpg
#   inflating: digits/train/9/Nine_full (161).jpg
#   inflating: digits/train/9/Nine_full (1932).jpg
#   inflating: digits/train/9/Nine_full (1225).jpg
#   inflating: digits/train/9/Nine_full (1721).jpg
#   inflating: digits/train/9/Nine_full (933).jpg
#   inflating: digits/train/9/Nine_full (928).jpg
#   inflating: digits/train/9/Nine_full (1085).jpg
#   inflating: digits/train/9/Nine_full (1028).jpg
#   inflating: digits/train/9/Nine_full (581).jpg
#   inflating: digits/train/9/Nine_full (1850).jpg
#   inflating: digits/train/9/Nine_full (1670).jpg
#   inflating: digits/train/9/Nine_full (1549).jpg
#   inflating: digits/train/9/Nine_full (1661).jpg
#   inflating: digits/train/9/Nine_full (1875).jpg
#   inflating: digits/train/9/Nine_full (1043).jpg
#   inflating: digits/train/9/Nine_full (1927).jpg
#   inflating: digits/train/9/Nine_full (224).jpg
#   inflating: digits/train/9/Nine_full (10).jpg
#   inflating: digits/train/9/Nine_full (16).jpg
#   inflating: digits/train/9/Nine_full (1780).jpg
#   inflating: digits/train/9/Nine_full (1847).jpg
#   inflating: digits/train/9/Nine_full (590).jpg
#   inflating: digits/train/9/Nine_full (473).jpg
#   inflating: digits/train/9/Nine_full (1959).jpg
#   inflating: digits/train/9/Nine_full (793).jpg
#   inflating: digits/train/9/Nine_full (885).jpg
#   inflating: digits/train/9/Nine_full (1997).jpg
#   inflating: digits/train/9/Nine_full (153).jpg
#   inflating: digits/train/9/Nine_full (1111).jpg
#   inflating: digits/train/9/Nine_full (149).jpg
#   inflating: digits/train/9/Nine_full (1745).jpg
#   inflating: digits/train/9/Nine_full (309).jpg
#   inflating: digits/train/9/Nine_full (188).jpg
#   inflating: digits/train/9/Nine_full (1324).jpg
#   inflating: digits/train/9/Nine_full (1194).jpg
#   inflating: digits/train/9/Nine_full (1497).jpg
#   inflating: digits/train/9/Nine_full (322).jpg
#   inflating: digits/train/9/Nine_full (450).jpg
#   inflating: digits/train/9/Nine_full (186).jpg
#   inflating: digits/train/9/Nine_full (1527).jpg
#   inflating: digits/train/9/Nine_full (424).jpg
#   inflating: digits/train/9/Nine_full (1581).jpg
#   inflating: digits/train/9/Nine_full (1641).jpg
#   inflating: digits/train/9/Nine_full (509).jpg
#   inflating: digits/train/9/Nine_full (769).jpg
#   inflating: digits/train/9/Nine_full (1007).jpg
#   inflating: digits/train/9/Nine_full (498).jpg
#   inflating: digits/train/9/Nine_full (1991).jpg
#   inflating: digits/train/9/Nine_full (1867).jpg
#   inflating: digits/train/9/Nine_full (263).jpg
#   inflating: digits/train/9/Nine_full (1097).jpg
#   inflating: digits/train/9/Nine_full (1046).jpg
#   inflating: digits/train/9/Nine_full (117).jpg
#   inflating: digits/train/9/Nine_full (1125).jpg
#   inflating: digits/train/9/Nine_full (393).jpg
#   inflating: digits/train/9/Nine_full (779).jpg
#   inflating: digits/train/9/Nine_full (1084).jpg
#   inflating: digits/train/9/Nine_full (916).jpg
#   inflating: digits/train/9/Nine_full (958).jpg
#   inflating: digits/train/9/Nine_full (514).jpg
#   inflating: digits/train/9/Nine_full (406).jpg
#   inflating: digits/train/9/Nine_full (345).jpg
#   inflating: digits/train/9/Nine_full (1298).jpg
#   inflating: digits/train/9/Nine_full (1789).jpg
#   inflating: digits/train/9/Nine_full (1687).jpg
#   inflating: digits/train/9/Nine_full (1761).jpg
#   inflating: digits/train/9/Nine_full (549).jpg
#   inflating: digits/train/9/Nine_full (1685).jpg
#   inflating: digits/train/9/Nine_full (1820).jpg
#   inflating: digits/train/9/Nine_full (798).jpg
#   inflating: digits/train/9/Nine_full (427).jpg
#   inflating: digits/train/9/Nine_full (1985).jpg
#   inflating: digits/train/9/Nine_full (760).jpg
#   inflating: digits/train/9/Nine_full (1622).jpg
#   inflating: digits/train/9/Nine_full (844).jpg
#   inflating: digits/train/9/Nine_full (837).jpg
#   inflating: digits/train/9/Nine_full (230).jpg
#   inflating: digits/train/9/Nine_full (1368).jpg
#   inflating: digits/train/9/Nine_full (1166).jpg
#   inflating: digits/train/9/Nine_full (1420).jpg
#   inflating: digits/train/9/Nine_full (167).jpg
#   inflating: digits/train/9/Nine_full (1667).jpg
#   inflating: digits/train/9/Nine_full (202).jpg
#   inflating: digits/train/9/Nine_full (338).jpg
#   inflating: digits/train/9/Nine_full (1659).jpg
#   inflating: digits/train/9/Nine_full (1658).jpg
#   inflating: digits/train/9/Nine_full (1813).jpg
#   inflating: digits/train/9/Nine_full (1291).jpg
#   inflating: digits/train/9/Nine_full (931).jpg
#   inflating: digits/train/9/Nine_full (156).jpg
#   inflating: digits/train/9/Nine_full (1241).jpg
#   inflating: digits/train/9/Nine_full (1192).jpg
#   inflating: digits/train/9/Nine_full (1445).jpg
#   inflating: digits/train/9/Nine_full (199).jpg
#   inflating: digits/train/9/Nine_full (260).jpg
#   inflating: digits/train/9/Nine_full (34).jpg
#   inflating: digits/train/9/Nine_full (574).jpg
#   inflating: digits/train/9/Nine_full (865).jpg
#   inflating: digits/train/9/Nine_full (1073).jpg
#   inflating: digits/train/9/Nine_full (1270).jpg
#   inflating: digits/train/9/Nine_full (959).jpg
#   inflating: digits/train/9/Nine_full (925).jpg
#   inflating: digits/train/9/Nine_full (548).jpg
#   inflating: digits/train/9/Nine_full (378).jpg
#   inflating: digits/train/9/Nine_full (652).jpg
#   inflating: digits/train/9/Nine_full (953).jpg
#   inflating: digits/train/9/Nine_full (1437).jpg
#   inflating: digits/train/9/Nine_full (298).jpg
#   inflating: digits/train/9/Nine_full (1616).jpg
#   inflating: digits/train/9/Nine_full (1066).jpg
#   inflating: digits/train/9/Nine_full (59).jpg
#   inflating: digits/train/9/Nine_full (1432).jpg
#   inflating: digits/train/9/Nine_full (1870).jpg
#   inflating: digits/train/9/Nine_full (968).jpg
#   inflating: digits/train/9/Nine_full (63).jpg
#   inflating: digits/train/9/Nine_full (772).jpg
#   inflating: digits/train/9/Nine_full (417).jpg
#   inflating: digits/train/9/Nine_full (375).jpg
#   inflating: digits/train/9/Nine_full (434).jpg
#   inflating: digits/train/9/Nine_full (929).jpg
#   inflating: digits/train/9/Nine_full (630).jpg
#   inflating: digits/train/9/Nine_full (902).jpg
#   inflating: digits/train/9/Nine_full (897).jpg
#   inflating: digits/train/9/Nine_full (50).jpg
#   inflating: digits/train/9/Nine_full (1866).jpg
#   inflating: digits/train/9/Nine_full (854).jpg
#   inflating: digits/train/9/Nine_full (326).jpg
#   inflating: digits/train/9/Nine_full (1636).jpg
#   inflating: digits/train/9/Nine_full (1922).jpg
#   inflating: digits/train/9/Nine_full (1925).jpg
#   inflating: digits/train/9/Nine_full (408).jpg
#   inflating: digits/train/9/Nine_full (523).jpg
#   inflating: digits/train/9/Nine_full (1205).jpg
#   inflating: digits/train/9/Nine_full (1654).jpg
#   inflating: digits/train/9/Nine_full (1935).jpg
#   inflating: digits/train/9/Nine_full (1987).jpg
#   inflating: digits/train/9/Nine_full (1609).jpg
#   inflating: digits/train/9/Nine_full (92).jpg
#   inflating: digits/train/9/Nine_full (23).jpg
#   inflating: digits/train/9/Nine_full (723).jpg
#   inflating: digits/train/9/Nine_full (1253).jpg
#   inflating: digits/train/9/Nine_full (564).jpg
#   inflating: digits/train/9/Nine_full (863).jpg
#   inflating: digits/train/9/Nine_full (1005).jpg
#   inflating: digits/train/9/Nine_full (1414).jpg
#   inflating: digits/train/9/Nine_full (1724).jpg
#   inflating: digits/train/9/Nine_full (871).jpg
#   inflating: digits/train/9/Nine_full (369).jpg
#   inflating: digits/train/9/Nine_full (568).jpg
#   inflating: digits/train/9/Nine_full (1362).jpg
#   inflating: digits/train/9/Nine_full (1711).jpg
#   inflating: digits/train/9/Nine_full (270).jpg
#   inflating: digits/train/9/Nine_full (1577).jpg
#   inflating: digits/train/9/Nine_full (836).jpg
#   inflating: digits/train/9/Nine_full (1555).jpg
#   inflating: digits/train/9/Nine_full (700).jpg
#   inflating: digits/train/9/Nine_full (33).jpg
#   inflating: digits/train/9/Nine_full (707).jpg
#   inflating: digits/train/9/Nine_full (78).jpg
#   inflating: digits/train/9/Nine_full (766).jpg
#   inflating: digits/train/9/Nine_full (1182).jpg
#   inflating: digits/train/9/Nine_full (749).jpg
#   inflating: digits/train/9/Nine_full (1424).jpg
#   inflating: digits/train/9/Nine_full (572).jpg
#   inflating: digits/train/9/Nine_full (1148).jpg
#   inflating: digits/train/9/Nine_full (1790).jpg
#   inflating: digits/train/9/Nine_full (1140).jpg
#   inflating: digits/train/9/Nine_full (903).jpg
#   inflating: digits/train/9/Nine_full (573).jpg
#   inflating: digits/train/9/Nine_full (132).jpg
#   inflating: digits/train/9/Nine_full (278).jpg
#   inflating: digits/train/9/Nine_full (821).jpg
#   inflating: digits/train/9/Nine_full (1828).jpg
#   inflating: digits/train/9/Nine_full (1962).jpg
#   inflating: digits/train/9/Nine_full (1528).jpg
#   inflating: digits/train/9/Nine_full (641).jpg
#   inflating: digits/train/9/Nine_full (437).jpg
#   inflating: digits/train/9/Nine_full (927).jpg
#   inflating: digits/train/9/Nine_full (1075).jpg
#   inflating: digits/train/9/Nine_full (1859).jpg
#   inflating: digits/train/9/Nine_full (397).jpg
#   inflating: digits/train/9/Nine_full (1269).jpg
#   inflating: digits/train/9/Nine_full (1201).jpg
#   inflating: digits/train/9/Nine_full (791).jpg
#   inflating: digits/train/9/Nine_full (191).jpg
#   inflating: digits/train/9/Nine_full (1330).jpg
#   inflating: digits/train/9/Nine_full (1552).jpg
#   inflating: digits/train/9/Nine_full (1704).jpg
#   inflating: digits/train/9/Nine_full (782).jpg
#   inflating: digits/train/9/Nine_full (1035).jpg
#   inflating: digits/train/9/Nine_full (1293).jpg
#   inflating: digits/train/9/Nine_full (1347).jpg
#   inflating: digits/train/9/Nine_full (886).jpg
#   inflating: digits/train/9/Nine_full (1499).jpg
#   inflating: digits/train/9/Nine_full (492).jpg
#   inflating: digits/train/9/Nine_full (670).jpg
#   inflating: digits/train/9/Nine_full (1261).jpg
#   inflating: digits/train/9/Nine_full (502).jpg
#   inflating: digits/train/9/Nine_full (577).jpg
#   inflating: digits/train/9/Nine_full (922).jpg
# ...
#   inflating: digits/train/3/Three_full (2026).jpg
#   inflating: digits/train/3/Three_full (200).jpg
#   inflating: digits/train/3/Three_full (397).jpg
#   inflating: digits/train/3/Three_full (1356).jpg
#   inflating: digits/train/3/Three_full (1729).jpg
#   inflating: digits/train/3/Three_full (50).jpg
#   inflating: digits/train/3/Three_full (694).jpg
#   inflating: digits/train/3/Three_full (1750).jpg
#   inflating: digits/train/3/Three_full (1550).jpg
#   inflating: digits/train/3/Three_full (184).jpg
#   inflating: digits/train/3/Three_full (1608).jpg
#   inflating: digits/train/3/Three_full (1438).jpg
#   inflating: digits/train/3/Three_full (222).jpg
#   inflating: digits/train/3/Three_full (1749).jpg
#   inflating: digits/train/3/Three_full (1517).jpg
#   inflating: digits/train/3/Three_full (1095).jpg
#   inflating: digits/train/3/Three_full (1072).jpg
#   inflating: digits/train/3/Three_full (1986).jpg
#   inflating: digits/train/3/Three_full (1933).jpg
#   inflating: digits/train/3/Three_full (1431).jpg
#   inflating: digits/train/3/Three_full (117).jpg
#   inflating: digits/train/3/Three_full (589).jpg
#   inflating: digits/train/3/Three_full (2069).jpg
#   inflating: digits/train/3/Three_full (1305).jpg
#   inflating: digits/train/3/Three_full (515).jpg
#   inflating: digits/train/3/Three_full (172).jpg
#   inflating: digits/train/3/Three_full (842).jpg
#   inflating: digits/train/3/Three_full (1611).jpg
#   inflating: digits/train/3/Three_full (1488).jpg
#   inflating: digits/train/3/Three_full (20).jpg
#   inflating: digits/train/3/Three_full (242).jpg
#   inflating: digits/train/3/Three_full (631).jpg
#   inflating: digits/train/3/Three_full (1948).jpg
#   inflating: digits/train/3/Three_full (124).jpg
#   inflating: digits/train/3/Three_full (591).jpg
#   inflating: digits/train/3/Three_full (1001).jpg
#   inflating: digits/train/3/Three_full (362).jpg
#   inflating: digits/train/3/Three_full (611).jpg
#   inflating: digits/train/3/Three_full (790).jpg
#   inflating: digits/train/3/Three_full (1505).jpg
#   inflating: digits/train/3/Three_full (528).jpg
#   inflating: digits/train/3/Three_full (1052).jpg
#   inflating: digits/train/3/Three_full (194).jpg
#   inflating: digits/train/3/Three_full (967).jpg
#   inflating: digits/train/3/Three_full (1400).jpg
#   inflating: digits/train/3/Three_full (78).jpg
#   inflating: digits/train/3/Three_full (262).jpg
#   inflating: digits/train/3/Three_full (1799).jpg
#   inflating: digits/train/3/Three_full (1841).jpg
#   inflating: digits/train/3/Three_full (598).jpg
#   inflating: digits/train/3/Three_full (1492).jpg
#   inflating: digits/train/3/Three_full (1909).jpg
#   inflating: digits/train/3/Three_full (1963).jpg
#   inflating: digits/train/3/Three_full (567).jpg
#   inflating: digits/train/3/Three_full (680).jpg
#   inflating: digits/train/3/Three_full (534).jpg
#   inflating: digits/train/3/Three_full (693).jpg
#   inflating: digits/train/3/Three_full (2046).jpg
#   inflating: digits/train/3/Three_full (2016).jpg
#   inflating: digits/train/3/Three_full (1450).jpg
#   inflating: digits/train/3/Three_full (330).jpg
#   inflating: digits/train/3/Three_full (565).jpg
#   inflating: digits/train/3/Three_full (838).jpg
#   inflating: digits/train/3/Three_full (1584).jpg
#   inflating: digits/train/3/Three_full (1613).jpg
#   inflating: digits/train/3/Three_full (1858).jpg
#   inflating: digits/train/3/Three_full (1263).jpg
#   inflating: digits/train/3/Three_full (1479).jpg
#   inflating: digits/train/3/Three_full (1990).jpg
#   inflating: digits/train/3/Three_full (1557).jpg
#   inflating: digits/train/3/Three_full (170).jpg
#   inflating: digits/train/3/Three_full (709).jpg
#   inflating: digits/train/3/Three_full (1482).jpg
#   inflating: digits/train/3/Three_full (1297).jpg
#   inflating: digits/train/3/Three_full (37).jpg
#   inflating: digits/train/3/Three_full (388).jpg
#   inflating: digits/train/3/Three_full (2196).jpg
#   inflating: digits/train/3/Three_full (1379).jpg
#   inflating: digits/train/3/Three_full (1117).jpg
#   inflating: digits/train/3/Three_full (456).jpg
#   inflating: digits/train/3/Three_full (922).jpg
#   inflating: digits/train/3/Three_full (926).jpg
#   inflating: digits/train/3/Three_full (661).jpg
#   inflating: digits/train/3/Three_full (55).jpg
#   inflating: digits/train/3/Three_full (1484).jpg
#   inflating: digits/train/3/Three_full (722).jpg
#   inflating: digits/train/3/Three_full (307).jpg
#   inflating: digits/train/3/Three_full (586).jpg
#   inflating: digits/train/3/Three_full (903).jpg
#   inflating: digits/train/3/Three_full (1152).jpg
#   inflating: digits/train/3/Three_full (918).jpg
#   inflating: digits/train/3/Three_full (1790).jpg
#   inflating: digits/train/3/Three_full (259).jpg
#   inflating: digits/train/3/Three_full (1883).jpg
#   inflating: digits/train/3/Three_full (2032).jpg
#   inflating: digits/train/3/Three_full (1605).jpg
#   inflating: digits/train/3/Three_full (326).jpg
#   inflating: digits/train/3/Three_full (516).jpg
#   inflating: digits/train/3/Three_full (1478).jpg
#   inflating: digits/train/3/Three_full (1717).jpg
#   inflating: digits/train/3/Three_full (1712).jpg
#   inflating: digits/train/3/Three_full (506).jpg
#   inflating: digits/train/3/Three_full (2163).jpg
#   inflating: digits/train/3/Three_full (1587).jpg
#   inflating: digits/train/3/Three_full (339).jpg
#   inflating: digits/train/3/Three_full (773).jpg
#   inflating: digits/train/3/Three_full (509).jpg
#   inflating: digits/train/3/Three_full (1430).jpg
#   inflating: digits/train/3/Three_full (1211).jpg
#   inflating: digits/train/3/Three_full (1204).jpg
#   inflating: digits/train/3/Three_full (592).jpg
#   inflating: digits/train/3/Three_full (313).jpg
#   inflating: digits/train/3/Three_full (1686).jpg
#   inflating: digits/train/3/Three_full (1481).jpg
#   inflating: digits/train/3/Three_full (39).jpg
#   inflating: digits/train/3/Three_full (840).jpg
#   inflating: digits/train/3/Three_full (1109).jpg
#   inflating: digits/train/3/Three_full (800).jpg
#   inflating: digits/train/3/Three_full (257).jpg
#   inflating: digits/train/3/Three_full (1170).jpg
#   inflating: digits/train/3/Three_full (892).jpg
#   inflating: digits/train/3/Three_full (351).jpg
#   inflating: digits/train/3/Three_full (2170).jpg
#   inflating: digits/train/3/Three_full (2128).jpg
#   inflating: digits/train/3/Three_full (3).jpg
#   inflating: digits/train/3/Three_full (1783).jpg
#   inflating: digits/train/3/Three_full (719).jpg
#   inflating: digits/train/3/Three_full (667).jpg
#   inflating: digits/train/3/Three_full (512).jpg
#   inflating: digits/train/3/Three_full (1221).jpg
#   inflating: digits/train/3/Three_full (1793).jpg
#   inflating: digits/train/3/Three_full (1077).jpg
#   inflating: digits/train/3/Three_full (471).jpg
#   inflating: digits/train/3/Three_full (942).jpg
#   inflating: digits/train/3/Three_full (559).jpg
#   inflating: digits/train/3/Three_full (1159).jpg
#   inflating: digits/train/3/Three_full (1908).jpg
#   inflating: digits/train/3/Three_full (1848).jpg
#   inflating: digits/train/3/Three_full (2087).jpg
#   inflating: digits/train/3/Three_full (1531).jpg
#   inflating: digits/train/3/Three_full (945).jpg
#   inflating: digits/train/3/Three_full (1907).jpg
#   inflating: digits/train/3/Three_full (1150).jpg
#   inflating: digits/train/3/Three_full (1654).jpg
#   inflating: digits/train/3/Three_full (1447).jpg
#   inflating: digits/train/3/Three_full (869).jpg
#   inflating: digits/train/3/Three_full (2089).jpg
#   inflating: digits/train/3/Three_full (714).jpg
#   inflating: digits/train/3/Three_full (236).jpg
#   inflating: digits/train/3/Three_full (203).jpg
#   inflating: digits/train/3/Three_full (1208).jpg
#   inflating: digits/train/3/Three_full (1352).jpg
#   inflating: digits/train/3/Three_full (1899).jpg
#   inflating: digits/train/3/Three_full (762).jpg
#   inflating: digits/train/3/Three_full (450).jpg
#   inflating: digits/train/3/Three_full (335).jpg
#   inflating: digits/train/3/Three_full (2121).jpg
#   inflating: digits/train/3/Three_full (1329).jpg
#   inflating: digits/train/3/Three_full (1266).jpg
#   inflating: digits/train/3/Three_full (270).jpg
#   inflating: digits/train/3/Three_full (2152).jpg
#   inflating: digits/train/3/Three_full (643).jpg
#   inflating: digits/train/3/Three_full (80).jpg
#   inflating: digits/train/3/Three_full (240).jpg
#   inflating: digits/train/3/Three_full (1407).jpg
#   inflating: digits/train/3/Three_full (1508).jpg
#   inflating: digits/train/3/Three_full (306).jpg
#   inflating: digits/train/3/Three_full (1291).jpg
#   inflating: digits/train/3/Three_full (2017).jpg
#   inflating: digits/train/3/Three_full (1098).jpg
#   inflating: digits/train/3/Three_full (1993).jpg
#   inflating: digits/train/3/Three_full (1120).jpg
#   inflating: digits/train/3/Three_full (520).jpg
#   inflating: digits/train/3/Three_full (284).jpg
#   inflating: digits/train/3/Three_full (301).jpg
#   inflating: digits/train/3/Three_full (1971).jpg
#   inflating: digits/train/3/Three_full (1996).jpg
#   inflating: digits/train/3/Three_full (1306).jpg
#   inflating: digits/train/3/Three_full (1736).jpg
#   inflating: digits/train/3/Three_full (1925).jpg
#   inflating: digits/train/3/Three_full (1516).jpg
#   inflating: digits/train/3/Three_full (1620).jpg
#   inflating: digits/train/3/Three_full (123).jpg
#   inflating: digits/train/3/Three_full (1143).jpg
#   inflating: digits/train/3/Three_full (1254).jpg
#   inflating: digits/train/3/Three_full (1146).jpg
#   inflating: digits/train/3/Three_full (681).jpg
#   inflating: digits/train/3/Three_full (265).jpg
#   inflating: digits/train/3/Three_full (1821).jpg
#   inflating: digits/train/3/Three_full (1480).jpg
#   inflating: digits/train/3/Three_full (854).jpg
#   inflating: digits/train/3/Three_full (2158).jpg
#   inflating: digits/train/3/Three_full (1761).jpg
#   inflating: digits/train/3/Three_full (829).jpg
#   inflating: digits/train/3/Three_full (1164).jpg
#   inflating: digits/train/3/Three_full (1199).jpg
#   inflating: digits/train/3/Three_full (181).jpg
#   inflating: digits/train/3/Three_full (2185).jpg
#   inflating: digits/train/3/Three_full (2189).jpg
#   inflating: digits/train/3/Three_full (1702).jpg
#   inflating: digits/train/3/Three_full (819).jpg
#   inflating: digits/train/3/Three_full (1958).jpg
#   inflating: digits/train/3/Three_full (1843).jpg
#   inflating: digits/train/3/Three_full (9).jpg
#   inflating: digits/train/3/Three_full (1571).jpg
#   inflating: digits/train/3/Three_full (51).jpg
#   inflating: digits/train/3/Three_full (1118).jpg
#   inflating: digits/train/3/Three_full (673).jpg
#   inflating: digits/train/3/Three_full (396).jpg
#   inflating: digits/train/3/Three_full (479).jpg
#   inflating: digits/train/3/Three_full (705).jpg
#   inflating: digits/train/3/Three_full (2173).jpg
#   inflating: digits/train/3/Three_full (1433).jpg
#   inflating: digits/train/3/Three_full (542).jpg
#   inflating: digits/train/3/Three_full (2114).jpg
#   inflating: digits/train/3/Three_full (543).jpg
#   inflating: digits/train/3/Three_full (111).jpg
#   inflating: digits/train/3/Three_full (1777).jpg
#   inflating: digits/train/3/Three_full (1006).jpg
#   inflating: digits/train/3/Three_full (2202).jpg
#   inflating: digits/train/3/Three_full (1449).jpg
#   inflating: digits/train/3/Three_full (797).jpg
#   inflating: digits/train/3/Three_full (1458).jpg
#   inflating: digits/train/3/Three_full (1768).jpg
#   inflating: digits/train/3/Three_full (1372).jpg
#   inflating: digits/train/3/Three_full (1078).jpg
#   inflating: digits/train/3/Three_full (1923).jpg
#   inflating: digits/train/3/Three_full (42).jpg
#   inflating: digits/train/3/Three_full (223).jpg
#   inflating: digits/train/3/Three_full (2027).jpg
#   inflating: digits/train/3/Three_full (491).jpg
#   inflating: digits/train/3/Three_full (1807).jpg
#   inflating: digits/train/3/Three_full (1802).jpg
#   inflating: digits/train/3/Three_full (1903).jpg
#   inflating: digits/train/3/Three_full (541).jpg
#   inflating: digits/train/3/Three_full (1047).jpg
#   inflating: digits/train/3/Three_full (441).jpg
#   inflating: digits/train/3/Three_full (1127).jpg
#   inflating: digits/train/3/Three_full (1244).jpg
#   inflating: digits/train/3/Three_full (1213).jpg
#   inflating: digits/train/3/Three_full (63).jpg
#   inflating: digits/train/3/Three_full (1832).jpg
#   inflating: digits/train/3/Three_full (1280).jpg
#   inflating: digits/train/3/Three_full (268).jpg
#   inflating: digits/train/3/Three_full (1512).jpg
#   inflating: digits/train/3/Three_full (628).jpg
#   inflating: digits/train/3/Three_full (1416).jpg
#   inflating: digits/train/3/Three_full (1075).jpg
#   inflating: digits/train/3/Three_full (858).jpg
#   inflating: digits/train/3/Three_full (1989).jpg
#   inflating: digits/train/3/Three_full (53).jpg
#   inflating: digits/train/3/Three_full (64).jpg
#   inflating: digits/train/3/Three_full (1302).jpg
#   inflating: digits/train/3/Three_full (1066).jpg
#   inflating: digits/train/3/Three_full (2095).jpg
#   inflating: digits/train/3/Three_full (1591).jpg
#   inflating: digits/train/3/Three_full (1125).jpg
#   inflating: digits/train/3/Three_full (609).jpg
#   inflating: digits/train/3/Three_full (115).jpg
#   inflating: digits/train/3/Three_full (2140).jpg
#   inflating: digits/train/3/Three_full (2072).jpg
#   inflating: digits/train/3/Three_full (579).jpg
#   inflating: digits/train/3/Three_full (646).jpg
#   inflating: digits/train/3/Three_full (605).jpg
#   inflating: digits/train/3/Three_full (2188).jpg
#   inflating: digits/train/3/Three_full (192).jpg
#   inflating: digits/train/3/Three_full (31).jpg
#   inflating: digits/train/3/Three_full (629).jpg
#   inflating: digits/train/3/Three_full (2138).jpg
#   inflating: digits/train/3/Three_full (1988).jpg
#   inflating: digits/train/3/Three_full (1670).jpg
#   inflating: digits/train/3/Three_full (309).jpg
#   inflating: digits/train/3/Three_full (1210).jpg
#   inflating: digits/train/3/Three_full (612).jpg
#   inflating: digits/train/3/Three_full (1453).jpg
#   inflating: digits/train/3/Three_full (1380).jpg
#   inflating: digits/train/3/Three_full (1570).jpg
#   inflating: digits/train/3/Three_full (2004).jpg
#   inflating: digits/train/3/Three_full (58).jpg
#   inflating: digits/train/3/Three_full (1829).jpg
#   inflating: digits/train/3/Three_full (2051).jpg
#   inflating: digits/train/3/Three_full (1270).jpg
#   inflating: digits/train/3/Three_full (803).jpg
#   inflating: digits/train/3/Three_full (1169).jpg
#   inflating: digits/train/3/Three_full (2060).jpg
#   inflating: digits/train/3/Three_full (1300).jpg
#   inflating: digits/train/3/Three_full (994).jpg
#   inflating: digits/train/3/Three_full (535).jpg
#   inflating: digits/train/3/Three_full (96).jpg
#   inflating: digits/train/3/Three_full (140).jpg
#   inflating: digits/train/3/Three_full (1068).jpg
#   inflating: digits/train/3/Three_full (148).jpg
#   inflating: digits/train/3/Three_full (1684).jpg
#   inflating: digits/train/3/Three_full (1140).jpg
#   inflating: digits/train/3/Three_full (827).jpg
#   inflating: digits/train/3/Three_full (1694).jpg
#   inflating: digits/train/3/Three_full (1055).jpg
#   inflating: digits/train/3/Three_full (1162).jpg
#   inflating: digits/train/3/Three_full (1423).jpg
#   inflating: digits/train/3/Three_full (1784).jpg
#   inflating: digits/train/3/Three_full (841).jpg
#   inflating: digits/train/3/Three_full (616).jpg
#   inflating: digits/train/3/Three_full (910).jpg
#   inflating: digits/train/3/Three_full (617).jpg
#   inflating: digits/train/3/Three_full (7).jpg
#   inflating: digits/train/3/Three_full (864).jpg
#   inflating: digits/train/3/Three_full (531).jpg
#   inflating: digits/train/3/Three_full (1599).jpg
#   inflating: digits/train/3/Three_full (572).jpg
#   inflating: digits/train/3/Three_full (1607).jpg

# %% [markdown]
# ## Data Visualization

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
import numpy as np

# %%
def plot_sample_images(base_path, images_per_class=2):
    # Get the list of subfolders (class names)
    classes = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
    classes.sort() # Ensure alphabetical order

    num_classes = len(classes)

    # Create a grid: Rows = Classes, Cols = images_per_class
    fig, axes = plt.subplots(num_classes, images_per_class, figsize=(images_per_class * 3, num_classes * 3))

    # If there is only one class, wrap axes in a list to keep the loop working
    if num_classes == 1:
        axes = [axes]

    for i, class_name in enumerate(classes):
        class_path = os.path.join(base_path, class_name)
        # Get all image files in this subfolder
        all_images = [f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        # Pick random samples
        sample_images = random.sample(all_images, min(images_per_class, len(all_images)))

        for j, img_name in enumerate(sample_images):
            img_path = os.path.join(class_path, img_name)
            img = Image.open(img_path)

            # Select the correct subplot
            ax = axes[i][j] if num_classes > 1 else axes[j]
            ax.imshow(img)
            ax.set_title(f"{class_name}\n{img_name}", fontsize=8)
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
train_path = '/content/digits/train'

plot_sample_images(train_path, images_per_class=2)

# %% [markdown]
# ## Data Analysis

# %%
# Plot a histogram to assess data distribution across classes

train_dir = '/content/digits/train'

# Get a list of all class directories
class_names = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]

# Count the number of images in each class
class_counts = {}
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    num_images = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
    class_counts[class_name] = num_images

# Convert to a pandas Series for easier plotting
import pandas as pd
df_counts = pd.Series(class_counts)

# Plotting the histogram (bar chart)
plt.figure(figsize=(10, 6))
sns.barplot(x=df_counts.index, y=df_counts.values, palette='viridis')
plt.title('Distribution of Images Across Classes')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_873/965344918.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_counts.index, y=df_counts.values, palette='viridis')

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Since neural networks see images as grids of numerical values representing pixel intensity, images must be standardized before being fed into the network. Standardization typically includes three basic operations:
#
# **Resizing:** Since the network expects an input of a fixed shape, providing images of different resolutions will cause the execution to fail. Therefore, we must ensure all images are adjusted to the same fixed resolution.
#
# **Normalization:** It is often beneficial to normalize pixel values, scaling them to have a consistent mean and standard deviation. This helps the model reach faster convergence during training.
#
# **Augmentation:** Data augmentation involves applying random transformations—such as rotations and translations—to prevent overfitting during the training phase. Important: This must be applied only to training data, NOT to test data, as doing so would modify and corrupt the evaluation task.

# %%
import torchvision.transforms as T

# Define the pipeline
training_transforms = T.Compose([
    T.Resize((64, 64)),                     # Standardize size. Keeping resolution low speeds up training
    T.ToTensor(),                             # Convert to Tensor
    T.Normalize(mean=[0.485, 0.456, 0.406],   # Center the data
                std=[0.229, 0.224, 0.225])
])

test_transforms = T.Compose([
    T.Resize((64, 64)),                     # Standardize size. Keeping resolution low speeds up training
    T.ToTensor(),                             # Convert to Matrix (0.0 - 1.0)
    T.Normalize(mean=[0.485, 0.456, 0.406],   # Center the data
                std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# To bridge the gap between our files and our code, we use **ImageFolder**.
# This class performs two operations:
#
#
# 1.   It turns folder names into numerical **labels**
# 2.   It applies our **transformations**
#
# It returns a **list of tuples** in the form (item, label).
# In our case, the item will be the image (represented as a tensor) and the label will be an integer.
#
# For any ImageFolder instance I, we can access the first (image, label) tuple with I[0], and we can access the image and the label respectively with I[0][0] and I[0][1]

# %%
import torch
import torchvision.datasets as datasets # Import datasets module

test_dir = '/content/digits/test'

# Define the sets with different transforms
train_dataset = datasets.ImageFolder(root=train_dir, transform=training_transforms)
test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transforms)

print(f"Number of images in training set (all classes): {len(train_dataset)}")
print(f"Number of images in testing set (all classes): {len(test_dataset)}")
# Out:
# Number of images in training set (all classes): 17238
# Number of images in testing set (all classes): 4317

# %%
# Print the shape of train dataset
print(train_dataset[0][0].shape)

# Print the shape of test dataset
print(test_dataset[0][0].shape)
# Out:
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])

# %% [markdown]
# The **DataLoader** is a class that serves several key functions:
#
#
# 1.   **Batching**: To manage the limited memory of GPUs, it is more efficient to process data in mini-batches rather than all at once.
# 2.   **Shuffling**: To ensure effective learning, it is recommended to shuffle the data during training. This prevents the network from learning patterns related to the order of the data rather than the features of the data itself.
# 3.   **Parallel Loading**: To efficiently handle data preparation and preprocessing, the DataLoader creates sub-processes (workers) that allow the CPU and GPU to work independently. This prevents the GPU from sitting idle while the CPU prepares the next batch.
#
# When iterating through a DataLoader, it returns two Tensors:
#
#
# 1.   A **4D Tensor of Images** with [32, 3, 224, 224] shape, where 32 are the images stacked together in the batch, 3 are the color channels (RGB), and 224x224 is the image resolution.
#
# 2.   A **1D Tensor of Labels** with [32] shape, containing the label for each image in the current batch.

# %%
from torch.utils.data import DataLoader

# Create the Training Loader
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,   # Always shuffle training data to ensure the model does not learn unwanted patterns,
                    # such as the first images are all aces of hearts (i.e., we want to avoid bias)
    num_workers=2   # Use 2 sub-processes to load data faster
)

# Create the Testing Loader
test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,  # No need to shuffle test data; it doesn't affect the score
    num_workers=2
)

# %% [markdown]
# ## Model Definition

# %%
# Fix the number of classes dynamically based on the dataset
num_classes = len(class_names)

# %% [markdown]
# ### Multi-Layer Perceptron

# %%
import torch.nn as nn
import torch.nn.functional as F

class DigitMLP(nn.Module):
    def __init__(self, num_classes=num_classes):
        super(DigitMLP, self).__init__()

        self.input_size = 3 * 64 * 64

        self.fc1 = nn.Linear(self.input_size, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, num_classes)

    def forward(self, x):
        # Flatten the image tensor
        x = x.view(-1, self.input_size)

        # Apply ReLU activation to hidden layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        # Output layer (no activation here, CrossEntropyLoss expects raw scores/logits)
        x = self.fc3(x)
        return x

print(f"MLP defined with {num_classes} output classes.")
# Out:
# MLP defined with 10 output classes.

# %% [markdown]
# ### Convolutional Neural Network (CNN)

# %% [markdown]
# Convolutional Neural Networks (CNNs) are the primary type of neural network used for computer vision tasks. They are typically composed of three types of layers:
#
#
# 1.   **Convolutional Layers**: These layers function as learnable filters. A convolution operation is performed between the input image and these filters to extract the features (or "spatial signatures") of the image. They are responsible for identifying everything from simple edges to complex objects.
# 2.   **Maxpooling Layers**: These layers are used to reduce the spatial dimensions (height and width) of the feature maps. This downsampling helps make the features "translation invariant" (meaning the network can recognize a pattern even if it shifts slightly) and significantly speeds up computation by reducing the number of parameters.
# 3.  **Fully Connected Layers**: Also known as Dense Layers, these are located at the end of the network. They take the high-level features extracted by the previous layers and use them to make the final classification or prediction.

# %%
class DigitCNN(nn.Module):
    def __init__(self, num_classes=num_classes):
        super(DigitCNN, self).__init__()

        # First convolutional block
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2) # Reduces dimensions by half

        # Second convolutional block
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)

        # Third convolutional block
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)

        # Fully connected layers
        # After 3 pooling layers (each reducing by a factor of 2),
        # 64 / 2 / 2 / 2 = 8. So the last feature map size is 64x8x8
        # Flattened size: 64 * 8 * 8
        self.fc1 = nn.Linear(64 * 8 * 8, 512)

        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        # Apply first conv -> ReLU -> pool
        x = self.pool(F.relu(self.conv1(x)))
        # Apply second conv -> ReLU -> pool
        x = self.pool(F.relu(self.conv2(x)))
        # Apply third conv -> ReLU -> pool
        x = self.pool(F.relu(self.conv3(x)))

        # Flatten the feature maps for the fully connected layer
        # Ensure the view operation matches the fc1 input size
        x = x.view(-1, 64 * 8 * 8)

        # Apply fully connected layers with ReLU activation
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

print(f"CNN defined with {num_classes} output classes.")
# Out:
# CNN defined with 10 output classes.

# %% [markdown]
#  ### Training Loop

# %%
from sklearn.metrics import confusion_matrix

# %%
# Define models
model_mlp = DigitMLP(num_classes=num_classes)
model_cnn = DigitCNN(num_classes=num_classes)

# %%
# Define Loss Function and Optimizers
criterion = nn.CrossEntropyLoss()

mlp_optimizer = torch.optim.Adam(model_mlp.parameters(), lr=0.001)
cnn_optimizer = torch.optim.Adam(model_cnn.parameters(), lr=0.001)

# %%
# Set device to GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

mlp_model = model_mlp.to(device)
cnn_model = model_cnn.to(device)

# %%
# Define number of epochs for training
num_epochs = 15

# %%
def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, device):
    # To store metrics for plotting later
    history = {'train_loss': [], 'train_acc': [], 'test_loss': [], 'test_acc': []}

    for epoch in range(num_epochs):
        # Set the model to training mode (Enables Dropout/Batch Norm)
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            # Move data to the same device as the model (CPU or GPU)
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward pass
            optimizer.zero_grad()   # Clear out old gradients
            loss.backward()         # Compute how much each weight contributed to the loss
            optimizer.step()        # Adjust the weights to reduce the loss

            # loss.item() is the average loss for the current batch
            # images.size(0) is the number of images in the current batch
            # This multiplication returns the total loss for the current batch
            running_loss += loss.item() * images.size(0)

            # get value (discarded) and index for the highest score
            _, predicted = torch.max(outputs.data, 1)

            # number of images classified so far in this epoch
            total_train += labels.size(0)

            # count the elements classified correctly (Boolean masking)
            correct_train += (predicted == labels).sum().item()

        # Calculate final metrics for the Training Epoch
        train_loss = running_loss / len(train_loader.dataset)
        train_accuracy = 100 * correct_train / total_train

        # Evaluation on the test set
        model.eval() # Set the model to evaluation mode (Freezes Dropout/Batch Norm)
        test_running_loss = 0.0
        correct_test = 0
        total_test = 0

        # Disable gradient calculation for evaluation (Saves memory and time)
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                # Weighted loss for the test batch
                test_running_loss += loss.item() * images.size(0)

                # Accuracy tracking for the test batch
                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        # Calculate final metrics for the Testing Epoch
        test_loss = test_running_loss / len(test_loader.dataset)
        test_accuracy = 100 * correct_test / total_test

        # Save metrics to history dictionary for later plotting
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_accuracy)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_accuracy)

        # Print the progress for the current epoch
        print(f'Epoch [{epoch+1}/{num_epochs}] | '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}% | '
              f'Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%')

    return history

# %%
# Training the MLP
history_mlp = train_model(model=mlp_model, train_loader=train_loader, test_loader=test_loader, criterion=criterion, optimizer=mlp_optimizer, num_epochs=num_epochs, device=device)
# Out:
# Epoch [1/15] | Train Loss: 2.3110, Train Acc: 24.89% | Test Loss: 1.9963, Test Acc: 26.92%
# Epoch [2/15] | Train Loss: 1.8162, Train Acc: 35.22% | Test Loss: 1.6950, Test Acc: 40.98%
# Epoch [3/15] | Train Loss: 1.7208, Train Acc: 39.63% | Test Loss: 1.7131, Test Acc: 38.13%
# Epoch [4/15] | Train Loss: 1.6543, Train Acc: 42.02% | Test Loss: 1.6217, Test Acc: 43.57%
# Epoch [5/15] | Train Loss: 1.6176, Train Acc: 43.37% | Test Loss: 1.5782, Test Acc: 44.17%
# Epoch [6/15] | Train Loss: 1.5851, Train Acc: 45.19% | Test Loss: 1.5953, Test Acc: 44.24%
# Epoch [7/15] | Train Loss: 1.5827, Train Acc: 45.12% | Test Loss: 1.5430, Test Acc: 47.37%
# Epoch [8/15] | Train Loss: 1.5429, Train Acc: 46.86% | Test Loss: 1.6201, Test Acc: 42.97%
# Epoch [9/15] | Train Loss: 1.5476, Train Acc: 46.80% | Test Loss: 1.6915, Test Acc: 40.61%
# Epoch [10/15] | Train Loss: 1.5245, Train Acc: 47.46% | Test Loss: 1.5059, Test Acc: 47.86%
# Epoch [11/15] | Train Loss: 1.5090, Train Acc: 48.20% | Test Loss: 1.5305, Test Acc: 47.60%
# Epoch [12/15] | Train Loss: 1.5237, Train Acc: 47.66% | Test Loss: 1.5930, Test Acc: 44.01%
# Epoch [13/15] | Train Loss: 1.4866, Train Acc: 49.10% | Test Loss: 1.5629, Test Acc: 46.79%
# Epoch [14/15] | Train Loss: 1.4808, Train Acc: 49.19% | Test Loss: 1.4677, Test Acc: 49.78%
# Epoch [15/15] | Train Loss: 1.4836, Train Acc: 48.94% | Test Loss: 1.4971, Test Acc: 49.06%

# %%
# Training the CNN
history_cnn = train_model(model=model_cnn, train_loader=train_loader, test_loader=test_loader, criterion=criterion, optimizer=cnn_optimizer, num_epochs=num_epochs, device=device)
# Out:
# Epoch [1/15] | Train Loss: 0.6598, Train Acc: 78.61% | Test Loss: 0.1705, Test Acc: 94.65%
# Epoch [2/15] | Train Loss: 0.1265, Train Acc: 96.22% | Test Loss: 0.1635, Test Acc: 94.93%
# Epoch [3/15] | Train Loss: 0.0559, Train Acc: 98.18% | Test Loss: 0.1020, Test Acc: 96.99%
# Epoch [4/15] | Train Loss: 0.0422, Train Acc: 98.70% | Test Loss: 0.1375, Test Acc: 96.22%
# Epoch [5/15] | Train Loss: 0.0266, Train Acc: 99.18% | Test Loss: 0.1203, Test Acc: 96.53%
# Epoch [6/15] | Train Loss: 0.0280, Train Acc: 99.01% | Test Loss: 0.1323, Test Acc: 97.08%
# Epoch [7/15] | Train Loss: 0.0207, Train Acc: 99.34% | Test Loss: 0.0997, Test Acc: 97.78%
# Epoch [8/15] | Train Loss: 0.0161, Train Acc: 99.44% | Test Loss: 0.1506, Test Acc: 96.66%
# Epoch [9/15] | Train Loss: 0.0201, Train Acc: 99.38% | Test Loss: 0.0937, Test Acc: 97.98%
# Epoch [10/15] | Train Loss: 0.0179, Train Acc: 99.50% | Test Loss: 0.1209, Test Acc: 97.50%
# Epoch [11/15] | Train Loss: 0.0150, Train Acc: 99.53% | Test Loss: 0.1214, Test Acc: 97.34%
# Epoch [12/15] | Train Loss: 0.0069, Train Acc: 99.78% | Test Loss: 0.1202, Test Acc: 97.66%
# Epoch [13/15] | Train Loss: 0.0154, Train Acc: 99.50% | Test Loss: 0.1127, Test Acc: 97.85%
# Epoch [14/15] | Train Loss: 0.0138, Train Acc: 99.54% | Test Loss: 0.0954, Test Acc: 98.17%
# Epoch [15/15] | Train Loss: 0.0167, Train Acc: 99.48% | Test Loss: 0.1144, Test Acc: 97.89%

# %% [markdown]
# ## Test

# %%
def plot_confusion_matrix(model, test_loader, class_names, device):
    # 1. Collect all predictions and true labels
    all_labels = []
    all_predictions = []

    model.eval() # Set to evaluation mode (turns off Dropout)

    with torch.no_grad(): # Disable gradient calculation to save memory
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)

            # Get the index of the highest score (the prediction)
            _, predicted = torch.max(outputs.data, 1)

            # Move data back to CPU and convert to numpy for sklearn
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    # 2. Compute the mathematical confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)

    # 3. Create the Visualization
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)

    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix: Model Errors at a Glance')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# Testing the MLP
plot_confusion_matrix(model=mlp_model, test_loader=test_loader, class_names=class_names, device=device)

# %%
# Testing the CNN
plot_confusion_matrix(model=cnn_model, test_loader=test_loader, class_names=class_names, device=device)

# %% [markdown]
# ## Droput

# %% [markdown]
# **Dropout** is a regularization technique used in neural networks to **reduce overfitting**. It involves **randomly "turning off"** (deactivating) a percentage of neurons during training. This forces the remaining active neurons to learn more robust patterns, as they cannot rely on the presence of the deactivated ones.
#
# Dropout is applied **only during training** and is disabled during evaluation/testing.

# %%
class DigitCNNWithDropout(nn.Module):
    def __init__(self, num_classes=num_classes, dropout_rate=0.5):
        super(DigitCNNWithDropout, self).__init__()

        # First convolutional block
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Second convolutional block
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)

        # Third convolutional block
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)

        # Fully connected layers
        # After 3 pooling layers (each reducing by a factor of 2),
        # 64 / 2 / 2 / 2 = 8. So the last feature map size is 64x8x8
        self.fc1 = nn.Linear(64 * 8 * 8, 512)
        self.dropout = nn.Dropout(dropout_rate) # Dropout layer
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        # Apply first conv -> ReLU -> pool
        x = self.pool(F.relu(self.conv1(x)))
        # Apply second conv -> ReLU -> pool
        x = self.pool(F.relu(self.conv2(x)))
        # Apply third conv -> ReLU -> pool
        x = self.pool(F.relu(self.conv3(x)))

        # Flatten the feature maps for the fully connected layer
        x = x.view(-1, 64 * 8 * 8)

        # Apply fully connected layers with ReLU activation and Dropout
        x = F.relu(self.fc1(x))
        x = self.dropout(x) # Apply dropout
        x = self.fc2(x)
        return x

print(f"CNN with Dropout defined with {num_classes} output classes and dropout rate of 0.5.")
# Out:
# CNN with Dropout defined with 10 output classes and dropout rate of 0.5.

# %%
# Train the model
model_cnn_dropout = DigitCNNWithDropout(num_classes=num_classes, dropout_rate=0.5)
model_cnn_dropout = model_cnn_dropout.to(device)
cnn_dropout_optimizer = torch.optim.Adam(model_cnn_dropout.parameters(), lr=0.001)

history_cnn_dropout = train_model(model=model_cnn_dropout, train_loader=train_loader, test_loader=test_loader, criterion=criterion, optimizer=cnn_dropout_optimizer, num_epochs=num_epochs, device=device)
# Out:
# Epoch [1/15] | Train Loss: 0.7350, Train Acc: 76.02% | Test Loss: 0.1966, Test Acc: 93.88%
# Epoch [2/15] | Train Loss: 0.1807, Train Acc: 94.48% | Test Loss: 0.1054, Test Acc: 96.85%
# Epoch [3/15] | Train Loss: 0.1008, Train Acc: 96.87% | Test Loss: 0.0895, Test Acc: 97.22%
# Epoch [4/15] | Train Loss: 0.0726, Train Acc: 97.62% | Test Loss: 0.0937, Test Acc: 97.13%
# Epoch [5/15] | Train Loss: 0.0578, Train Acc: 98.22% | Test Loss: 0.0749, Test Acc: 97.98%
# Epoch [6/15] | Train Loss: 0.0412, Train Acc: 98.68% | Test Loss: 0.0873, Test Acc: 97.89%
# Epoch [7/15] | Train Loss: 0.0417, Train Acc: 98.63% | Test Loss: 0.0989, Test Acc: 97.48%
# Epoch [8/15] | Train Loss: 0.0328, Train Acc: 98.89% | Test Loss: 0.0677, Test Acc: 98.19%
# Epoch [9/15] | Train Loss: 0.0302, Train Acc: 99.02% | Test Loss: 0.0742, Test Acc: 98.24%
# Epoch [10/15] | Train Loss: 0.0268, Train Acc: 99.19% | Test Loss: 0.0815, Test Acc: 98.08%
# Epoch [11/15] | Train Loss: 0.0288, Train Acc: 99.08% | Test Loss: 0.0773, Test Acc: 98.24%
# Epoch [12/15] | Train Loss: 0.0235, Train Acc: 99.28% | Test Loss: 0.0753, Test Acc: 98.08%
# Epoch [13/15] | Train Loss: 0.0239, Train Acc: 99.30% | Test Loss: 0.0792, Test Acc: 98.05%
# Epoch [14/15] | Train Loss: 0.0141, Train Acc: 99.58% | Test Loss: 0.1384, Test Acc: 97.59%
# Epoch [15/15] | Train Loss: 0.0216, Train Acc: 99.32% | Test Loss: 0.1401, Test Acc: 96.73%

# %%
# Test the model
plot_confusion_matrix(model=model_cnn_dropout, test_loader=test_loader, class_names=class_names, device=device)
